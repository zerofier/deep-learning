# %%
import matplotlib.pyplot as plot
import numpy as np

x = np.arange(-4, 4, 0.1)
y = np.exp(x) + 1e-6

# plot.plot(x, y)

# %%
import pandas as pd

files = [
    # "rl_003/loss_history_20240822T220817.csv",
    # "rl_003/loss_history_20240824T111930.csv",
    # "rl_003/loss_history_20240824T224630.csv",
    "rl_003/loss_history_20240826T235945.csv"
]

df = pd.DataFrame()
for file in files:
    df = pd.concat([df, pd.read_csv(file)], ignore_index=True)
df.loc[:, ["loss", "total_reward"]].plot(subplots=True, grid=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df.plot.scatter(x="loss", y="total_reward")
# Out:
# <Axes: xlabel='loss', ylabel='total_reward'>
